# %%
# Imports
import re
import cv2
import os
from imutils import paths
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
import shutil
import random
from tqdm.notebook import tqdm
from urllib import request
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.chdir("/Users/emmettsexton/Dropbox/Mac (2)/Desktop/BSE/Trimester 3/03 DL Images/02 Project/")
# Out:
# '/Users/emmettsexton/Dropbox/Mac (2)/Desktop/BSE/Trimester 3/03 DL Images/02 Project'

# %% [markdown]
# # Load train, validation, and test images plus their labels
# Then create dataframes for each to be used in the image generators below

# %%
# Load the file paths for all available images from the competition
train_paths = list(paths.list_images("./00 Data/train")) 
val_paths = list(paths.list_images("./00 Data/val")) 
test_paths = list(paths.list_images("./00 Data/test")) 

# Print the number of images in each set
print(f"Training set size: {len(train_paths)}")
print(f"Validation set size: {len(val_paths)}")
print(f"Test set size: {len(test_paths)}")
# Out:
# Training set size: 11541
# Validation set size: 2473
# Test set size: 2474

# %%
# Load labels for all images
labels = pd.read_csv('./00 Data/train_labels.csv')

# Load all image paths
all_image_paths = list(paths.list_images("./00 Data"))

# Extract the ID from each image file path
def extract_id(file_path):
    base_name = os.path.basename(file_path)
    file_id, _ = os.path.splitext(base_name)
    return file_id

# Create a DataFrame from the image paths
image_data = {
    'file_path': all_image_paths,
    'id': [extract_id(path) for path in all_image_paths]
}
image_df = pd.DataFrame(image_data)

# Merge the image paths with the labels
merged_df = pd.merge(image_df, labels, on='id', how='inner')

# %%
# Split merged_df into training, validation, and test DataFrames
train_df = merged_df[merged_df['file_path'].isin(train_paths)]
val_df = merged_df[merged_df['file_path'].isin(val_paths)]
test_df = merged_df[merged_df['file_path'].isin(test_paths)]

# %% [markdown]
# # Create train, validation, and test image generators
# Only augmenting the training images

# %%
# Define the data generator for training with augmentations
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    shear_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2]
)
# Define the ImageDataGenerator for validation and test (without augmentations)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Specify the columns for the generator
image_column = 'file_path'
label_columns = labels.columns[1:]  # all columns except 'id' are labels

# Create training generator
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col=image_column,
    y_col=label_columns.tolist(),
    target_size=(128, 128), 
    batch_size=32,
    class_mode='raw',
    shuffle=True
)

# Create validation generator
validation_generator = val_test_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col=image_column,
    y_col=label_columns.tolist(),
    target_size=(128, 128),
    batch_size=32,
    class_mode='raw',
    shuffle=True
)

# Create test generator
test_generator = val_test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col=image_column,
    y_col=label_columns.tolist(),
    target_size=(128, 128),
    batch_size=32,
    class_mode='raw',
    shuffle=False
)
# Out:
# Found 11541 validated image filenames.
# Found 2473 validated image filenames.
# Found 2474 validated image filenames.

# %% [markdown]
# # Define and fit our preferred model

# %%
# Define the EarlyStopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',    
    patience=20,           
    verbose=1,             
    restore_best_weights=True  
)

# Fit model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), input_shape=(128, 128, 3), kernel_initializer=tf.keras.initializers.HeNormal()),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),

    tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer=tf.keras.initializers.HeNormal()),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(128, kernel_initializer=tf.keras.initializers.HeNormal()),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(len(label_columns), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=300,
    callbacks=[early_stopping_callback]
)

# Save the entire model
model.save('./01 Models/final_model.keras')
# Out:
# Epoch 1/300
# 2024-06-26 09:46:06.767783: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 361/361 [==============================] - ETA: 0s - loss: 1.8576 - accuracy: 0.3126
# 2024-06-26 09:47:22.057151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 361/361 [==============================] - 80s 213ms/step - loss: 1.8576 - accuracy: 0.3126 - val_loss: 2.0430 - val_accuracy: 0.1852
# Epoch 2/300
# 361/361 [==============================] - 72s 198ms/step - loss: 1.6135 - accuracy: 0.3816 - val_loss: 1.6647 - val_accuracy: 0.3599
# Epoch 3/300
# 361/361 [==============================] - 75s 206ms/step - loss: 1.5175 - accuracy: 0.4216 - val_loss: 1.6953 - val_accuracy: 0.3352
# Epoch 4/300
# 361/361 [==============================] - 78s 214ms/step - loss: 1.4516 - accuracy: 0.4467 - val_loss: 1.4631 - val_accuracy: 0.4561
# Epoch 5/300
# 361/361 [==============================] - 83s 229ms/step - loss: 1.3914 - accuracy: 0.4766 - val_loss: 1.5734 - val_accuracy: 0.3688
# Epoch 6/300
# 361/361 [==============================] - 88s 241ms/step - loss: 1.3346 - accuracy: 0.5007 - val_loss: 1.7381 - val_accuracy: 0.3963
# Epoch 7/300
# 361/361 [==============================] - 93s 258ms/step - loss: 1.2976 - accuracy: 0.5193 - val_loss: 1.6885 - val_accuracy: 0.3700
# Epoch 8/300
# 361/361 [==============================] - 80s 221ms/step - loss: 1.2539 - accuracy: 0.5346 - val_loss: 1.3868 - val_accuracy: 0.4836
# Epoch 9/300
# 361/361 [==============================] - 80s 221ms/step - loss: 1.2203 - accuracy: 0.5502 - val_loss: 1.2000 - val_accuracy: 0.5609
# Epoch 10/300
# 361/361 [==============================] - 84s 231ms/step - loss: 1.1909 - accuracy: 0.5631 - val_loss: 1.6378 - val_accuracy: 0.4909
# Epoch 11/300
# 361/361 [==============================] - 97s 268ms/step - loss: 1.1626 - accuracy: 0.5727 - val_loss: 1.1809 - val_accuracy: 0.5754
# Epoch 12/300
# 361/361 [==============================] - 92s 255ms/step - loss: 1.1495 - accuracy: 0.5811 - val_loss: 1.1688 - val_accuracy: 0.5843
# Epoch 13/300
# 361/361 [==============================] - 96s 265ms/step - loss: 1.1035 - accuracy: 0.5968 - val_loss: 1.4765 - val_accuracy: 0.4683
# Epoch 14/300
# 361/361 [==============================] - 98s 272ms/step - loss: 1.0931 - accuracy: 0.6012 - val_loss: 1.2752 - val_accuracy: 0.5160
# Epoch 15/300
# 361/361 [==============================] - 101s 278ms/step - loss: 1.0695 - accuracy: 0.6097 - val_loss: 1.1744 - val_accuracy: 0.5714
# Epoch 16/300
# 361/361 [==============================] - 101s 280ms/step - loss: 1.0491 - accuracy: 0.6183 - val_loss: 1.0762 - val_accuracy: 0.6098
# Epoch 17/300
# 361/361 [==============================] - 102s 282ms/step - loss: 1.0285 - accuracy: 0.6215 - val_loss: 1.3603 - val_accuracy: 0.5742
# Epoch 18/300
# 361/361 [==============================] - 100s 276ms/step - loss: 1.0067 - accuracy: 0.6364 - val_loss: 0.9817 - val_accuracy: 0.6454
# Epoch 19/300
# 361/361 [==============================] - 108s 295ms/step - loss: 0.9938 - accuracy: 0.6360 - val_loss: 1.1451 - val_accuracy: 0.5867
# Epoch 20/300
# 361/361 [==============================] - 100s 277ms/step - loss: 0.9767 - accuracy: 0.6426 - val_loss: 1.0146 - val_accuracy: 0.6494
# Epoch 21/300
# 361/361 [==============================] - 100s 276ms/step - loss: 0.9568 - accuracy: 0.6518 - val_loss: 1.0570 - val_accuracy: 0.6353
# Epoch 22/300
# 361/361 [==============================] - 106s 293ms/step - loss: 0.9367 - accuracy: 0.6569 - val_loss: 0.9523 - val_accuracy: 0.6644
# Epoch 23/300
# 361/361 [==============================] - 101s 278ms/step - loss: 0.9195 - accuracy: 0.6605 - val_loss: 1.0410 - val_accuracy: 0.6377
# Epoch 24/300
# 361/361 [==============================] - 99s 274ms/step - loss: 0.9072 - accuracy: 0.6715 - val_loss: 1.0103 - val_accuracy: 0.6353
# Epoch 25/300
# 361/361 [==============================] - 123s 340ms/step - loss: 0.8922 - accuracy: 0.6798 - val_loss: 1.4118 - val_accuracy: 0.5338
# Epoch 26/300
# 361/361 [==============================] - 108s 299ms/step - loss: 0.8894 - accuracy: 0.6787 - val_loss: 0.9896 - val_accuracy: 0.6450
# Epoch 27/300
# 361/361 [==============================] - 111s 306ms/step - loss: 0.8659 - accuracy: 0.6846 - val_loss: 0.9846 - val_accuracy: 0.6510
# Epoch 28/300
# 361/361 [==============================] - 104s 288ms/step - loss: 0.8618 - accuracy: 0.6860 - val_loss: 0.9272 - val_accuracy: 0.6619
# Epoch 29/300
# 361/361 [==============================] - 121s 334ms/step - loss: 0.8512 - accuracy: 0.6920 - val_loss: 0.9763 - val_accuracy: 0.6539
# Epoch 30/300
# 361/361 [==============================] - 99s 273ms/step - loss: 0.8380 - accuracy: 0.6991 - val_loss: 0.9065 - val_accuracy: 0.6737
# Epoch 31/300
# 361/361 [==============================] - 104s 287ms/step - loss: 0.8299 - accuracy: 0.7059 - val_loss: 1.0707 - val_accuracy: 0.5973
# Epoch 32/300
# 361/361 [==============================] - 105s 290ms/step - loss: 0.8151 - accuracy: 0.7029 - val_loss: 0.9765 - val_accuracy: 0.6502
# Epoch 33/300
# 361/361 [==============================] - 102s 281ms/step - loss: 0.8109 - accuracy: 0.7067 - val_loss: 0.9041 - val_accuracy: 0.6696
# Epoch 34/300
# 361/361 [==============================] - 103s 284ms/step - loss: 0.7929 - accuracy: 0.7148 - val_loss: 0.8029 - val_accuracy: 0.7258
# Epoch 35/300
# 361/361 [==============================] - 107s 296ms/step - loss: 0.7783 - accuracy: 0.7248 - val_loss: 0.8592 - val_accuracy: 0.6858
# Epoch 36/300
# 361/361 [==============================] - 108s 299ms/step - loss: 0.7850 - accuracy: 0.7218 - val_loss: 1.0323 - val_accuracy: 0.6239
# Epoch 37/300
# 361/361 [==============================] - 105s 289ms/step - loss: 0.7789 - accuracy: 0.7216 - val_loss: 0.8268 - val_accuracy: 0.7097
# Epoch 38/300
# 361/361 [==============================] - 106s 294ms/step - loss: 0.7599 - accuracy: 0.7274 - val_loss: 0.7854 - val_accuracy: 0.7327
# Epoch 39/300
# 361/361 [==============================] - 110s 303ms/step - loss: 0.7537 - accuracy: 0.7300 - val_loss: 0.8123 - val_accuracy: 0.7076
# Epoch 40/300
# 361/361 [==============================] - 105s 290ms/step - loss: 0.7488 - accuracy: 0.7330 - val_loss: 0.7414 - val_accuracy: 0.7533
# Epoch 41/300
# 361/361 [==============================] - 110s 302ms/step - loss: 0.7469 - accuracy: 0.7356 - val_loss: 0.9231 - val_accuracy: 0.6611
# Epoch 42/300
# 361/361 [==============================] - 121s 335ms/step - loss: 0.7384 - accuracy: 0.7368 - val_loss: 0.8010 - val_accuracy: 0.7283
# Epoch 43/300
# 361/361 [==============================] - 110s 304ms/step - loss: 0.7138 - accuracy: 0.7427 - val_loss: 0.7866 - val_accuracy: 0.7287
# Epoch 44/300
# 361/361 [==============================] - 104s 289ms/step - loss: 0.7141 - accuracy: 0.7457 - val_loss: 0.7408 - val_accuracy: 0.7570
# Epoch 45/300
# 361/361 [==============================] - 108s 299ms/step - loss: 0.7090 - accuracy: 0.7472 - val_loss: 0.7184 - val_accuracy: 0.7541
# Epoch 46/300
# 361/361 [==============================] - 107s 296ms/step - loss: 0.6987 - accuracy: 0.7458 - val_loss: 0.7647 - val_accuracy: 0.7331
# Epoch 47/300
# 361/361 [==============================] - 113s 312ms/step - loss: 0.6938 - accuracy: 0.7516 - val_loss: 0.9223 - val_accuracy: 0.6611
# Epoch 48/300
# 361/361 [==============================] - 107s 295ms/step - loss: 0.6898 - accuracy: 0.7576 - val_loss: 0.7928 - val_accuracy: 0.7145
# Epoch 49/300
# 361/361 [==============================] - 105s 291ms/step - loss: 0.6777 - accuracy: 0.7593 - val_loss: 0.7716 - val_accuracy: 0.7299
# Epoch 50/300
# 361/361 [==============================] - 111s 307ms/step - loss: 0.6731 - accuracy: 0.7570 - val_loss: 0.7785 - val_accuracy: 0.7254
# Epoch 51/300
# 361/361 [==============================] - 198s 548ms/step - loss: 0.6707 - accuracy: 0.7562 - val_loss: 0.7670 - val_accuracy: 0.7315
# Epoch 52/300
# 361/361 [==============================] - 191s 525ms/step - loss: 0.6656 - accuracy: 0.7623 - val_loss: 0.7728 - val_accuracy: 0.7258
# Epoch 53/300
# 361/361 [==============================] - 162s 449ms/step - loss: 0.6499 - accuracy: 0.7611 - val_loss: 0.7716 - val_accuracy: 0.7202
# Epoch 54/300
# 361/361 [==============================] - 149s 412ms/step - loss: 0.6414 - accuracy: 0.7732 - val_loss: 0.7156 - val_accuracy: 0.7469
# Epoch 55/300
# 361/361 [==============================] - 174s 482ms/step - loss: 0.6502 - accuracy: 0.7704 - val_loss: 0.7552 - val_accuracy: 0.7359
# Epoch 56/300
# 361/361 [==============================] - 140s 388ms/step - loss: 0.6456 - accuracy: 0.7679 - val_loss: 0.7425 - val_accuracy: 0.7359
# Epoch 57/300
# 361/361 [==============================] - 133s 368ms/step - loss: 0.6366 - accuracy: 0.7704 - val_loss: 0.8279 - val_accuracy: 0.7089
# Epoch 58/300
# 361/361 [==============================] - 109s 301ms/step - loss: 0.6255 - accuracy: 0.7783 - val_loss: 0.7778 - val_accuracy: 0.7250
# Epoch 59/300
# 361/361 [==============================] - 111s 308ms/step - loss: 0.6221 - accuracy: 0.7799 - val_loss: 0.7592 - val_accuracy: 0.7331
# Epoch 60/300
# 361/361 [==============================] - 131s 361ms/step - loss: 0.6133 - accuracy: 0.7802 - val_loss: 0.7946 - val_accuracy: 0.7129
# Epoch 61/300
# 361/361 [==============================] - 118s 327ms/step - loss: 0.6139 - accuracy: 0.7804 - val_loss: 0.7354 - val_accuracy: 0.7473
# Epoch 62/300
# 361/361 [==============================] - 127s 350ms/step - loss: 0.6214 - accuracy: 0.7769 - val_loss: 0.6740 - val_accuracy: 0.7630
# Epoch 63/300
# 361/361 [==============================] - 118s 324ms/step - loss: 0.6123 - accuracy: 0.7841 - val_loss: 0.7164 - val_accuracy: 0.7493
# Epoch 64/300
# 361/361 [==============================] - 138s 381ms/step - loss: 0.6106 - accuracy: 0.7838 - val_loss: 0.7056 - val_accuracy: 0.7517
# Epoch 65/300
# 361/361 [==============================] - 117s 323ms/step - loss: 0.5921 - accuracy: 0.7891 - val_loss: 0.7222 - val_accuracy: 0.7602
# Epoch 66/300
# 361/361 [==============================] - 102s 283ms/step - loss: 0.5858 - accuracy: 0.7907 - val_loss: 0.6783 - val_accuracy: 0.7638
# Epoch 67/300
# 361/361 [==============================] - 99s 274ms/step - loss: 0.6001 - accuracy: 0.7876 - val_loss: 0.6763 - val_accuracy: 0.7655
# Epoch 68/300
# 361/361 [==============================] - 101s 279ms/step - loss: 0.5849 - accuracy: 0.7939 - val_loss: 0.6540 - val_accuracy: 0.7784
# Epoch 69/300
# 361/361 [==============================] - 100s 275ms/step - loss: 0.5925 - accuracy: 0.7927 - val_loss: 0.7127 - val_accuracy: 0.7598
# Epoch 70/300
# 361/361 [==============================] - 102s 281ms/step - loss: 0.5707 - accuracy: 0.7981 - val_loss: 0.8364 - val_accuracy: 0.7113
# Epoch 71/300
# 361/361 [==============================] - 102s 281ms/step - loss: 0.5767 - accuracy: 0.7938 - val_loss: 0.6799 - val_accuracy: 0.7748
# Epoch 72/300
# 361/361 [==============================] - 101s 278ms/step - loss: 0.5590 - accuracy: 0.7972 - val_loss: 0.7906 - val_accuracy: 0.7214
# Epoch 73/300
# 361/361 [==============================] - 99s 272ms/step - loss: 0.5672 - accuracy: 0.7984 - val_loss: 0.7542 - val_accuracy: 0.7545
# Epoch 74/300
# 361/361 [==============================] - 96s 265ms/step - loss: 0.5737 - accuracy: 0.7966 - val_loss: 0.6538 - val_accuracy: 0.7853
# Epoch 75/300
# 361/361 [==============================] - 97s 267ms/step - loss: 0.5567 - accuracy: 0.8027 - val_loss: 0.6649 - val_accuracy: 0.7695
# Epoch 76/300
# 361/361 [==============================] - 98s 271ms/step - loss: 0.5566 - accuracy: 0.8019 - val_loss: 0.6905 - val_accuracy: 0.7651
# Epoch 77/300
# 361/361 [==============================] - 101s 280ms/step - loss: 0.5530 - accuracy: 0.8020 - val_loss: 0.7036 - val_accuracy: 0.7461
# Epoch 78/300
# 361/361 [==============================] - 105s 291ms/step - loss: 0.5445 - accuracy: 0.8071 - val_loss: 0.7254 - val_accuracy: 0.7465
# Epoch 79/300
# 361/361 [==============================] - 104s 287ms/step - loss: 0.5524 - accuracy: 0.8054 - val_loss: 0.6685 - val_accuracy: 0.7736
# Epoch 80/300
# 361/361 [==============================] - 101s 278ms/step - loss: 0.5487 - accuracy: 0.8078 - val_loss: 0.6830 - val_accuracy: 0.7634
# Epoch 81/300
# 361/361 [==============================] - 101s 279ms/step - loss: 0.5433 - accuracy: 0.8048 - val_loss: 0.6534 - val_accuracy: 0.7820
# Epoch 82/300
# 361/361 [==============================] - 100s 277ms/step - loss: 0.5469 - accuracy: 0.8076 - val_loss: 0.6882 - val_accuracy: 0.7541
# Epoch 83/300
# 361/361 [==============================] - 104s 288ms/step - loss: 0.5268 - accuracy: 0.8128 - val_loss: 0.6322 - val_accuracy: 0.7849
# Epoch 84/300
# 361/361 [==============================] - 121s 333ms/step - loss: 0.5296 - accuracy: 0.8119 - val_loss: 0.7206 - val_accuracy: 0.7537
# Epoch 85/300
# 361/361 [==============================] - 109s 302ms/step - loss: 0.5405 - accuracy: 0.8079 - val_loss: 0.6228 - val_accuracy: 0.7942
# Epoch 86/300
# 361/361 [==============================] - 110s 303ms/step - loss: 0.5201 - accuracy: 0.8108 - val_loss: 0.6460 - val_accuracy: 0.7857
# Epoch 87/300
# 361/361 [==============================] - 114s 314ms/step - loss: 0.5242 - accuracy: 0.8163 - val_loss: 0.6184 - val_accuracy: 0.7930
# Epoch 88/300
# 361/361 [==============================] - 112s 309ms/step - loss: 0.5174 - accuracy: 0.8167 - val_loss: 0.7116 - val_accuracy: 0.7501
# Epoch 89/300
# 361/361 [==============================] - 113s 312ms/step - loss: 0.5224 - accuracy: 0.8128 - val_loss: 0.7144 - val_accuracy: 0.7545
# Epoch 90/300
# 361/361 [==============================] - 116s 320ms/step - loss: 0.5121 - accuracy: 0.8188 - val_loss: 0.6134 - val_accuracy: 0.7942
# Epoch 91/300
# 361/361 [==============================] - 117s 322ms/step - loss: 0.5129 - accuracy: 0.8167 - val_loss: 0.6690 - val_accuracy: 0.7614
# Epoch 92/300
# 361/361 [==============================] - 116s 321ms/step - loss: 0.5047 - accuracy: 0.8244 - val_loss: 0.8479 - val_accuracy: 0.7384
# Epoch 93/300
# 361/361 [==============================] - 121s 333ms/step - loss: 0.5142 - accuracy: 0.8184 - val_loss: 0.7918 - val_accuracy: 0.7214
# Epoch 94/300
# 361/361 [==============================] - 121s 335ms/step - loss: 0.4964 - accuracy: 0.8217 - val_loss: 0.6799 - val_accuracy: 0.7675
# Epoch 95/300
# 361/361 [==============================] - 123s 340ms/step - loss: 0.4990 - accuracy: 0.8230 - val_loss: 0.7084 - val_accuracy: 0.7545
# Epoch 96/300
# 361/361 [==============================] - 120s 332ms/step - loss: 0.4980 - accuracy: 0.8238 - val_loss: 0.5988 - val_accuracy: 0.7942
# Epoch 97/300
# 361/361 [==============================] - 126s 347ms/step - loss: 0.4962 - accuracy: 0.8228 - val_loss: 0.6363 - val_accuracy: 0.7881
# Epoch 98/300
# 361/361 [==============================] - 123s 339ms/step - loss: 0.4946 - accuracy: 0.8252 - val_loss: 1.2662 - val_accuracy: 0.6777
# Epoch 99/300
# 361/361 [==============================] - 121s 334ms/step - loss: 0.4938 - accuracy: 0.8249 - val_loss: 0.6097 - val_accuracy: 0.7918
# Epoch 100/300
# 361/361 [==============================] - 125s 344ms/step - loss: 0.4927 - accuracy: 0.8241 - val_loss: 0.6268 - val_accuracy: 0.7918
# Epoch 101/300
# 361/361 [==============================] - 124s 341ms/step - loss: 0.4824 - accuracy: 0.8261 - val_loss: 0.7011 - val_accuracy: 0.7610
# Epoch 102/300
# 361/361 [==============================] - 121s 333ms/step - loss: 0.4834 - accuracy: 0.8284 - val_loss: 0.6943 - val_accuracy: 0.7521
# Epoch 103/300
# 361/361 [==============================] - 116s 319ms/step - loss: 0.4845 - accuracy: 0.8300 - val_loss: 0.6021 - val_accuracy: 0.7958
# Epoch 104/300
# 361/361 [==============================] - 113s 311ms/step - loss: 0.4727 - accuracy: 0.8274 - val_loss: 0.5888 - val_accuracy: 0.8091
# Epoch 105/300
# 361/361 [==============================] - 113s 313ms/step - loss: 0.4775 - accuracy: 0.8305 - val_loss: 0.6383 - val_accuracy: 0.7913
# Epoch 106/300
# 361/361 [==============================] - 112s 310ms/step - loss: 0.4759 - accuracy: 0.8318 - val_loss: 0.6194 - val_accuracy: 0.7861
# Epoch 107/300
# 361/361 [==============================] - 111s 306ms/step - loss: 0.4614 - accuracy: 0.8368 - val_loss: 0.6017 - val_accuracy: 0.8019
# Epoch 108/300
# 361/361 [==============================] - 111s 307ms/step - loss: 0.4629 - accuracy: 0.8340 - val_loss: 0.6403 - val_accuracy: 0.8047
# Epoch 109/300
# 361/361 [==============================] - 113s 311ms/step - loss: 0.4606 - accuracy: 0.8380 - val_loss: 0.6050 - val_accuracy: 0.7942
# Epoch 110/300
# 361/361 [==============================] - 114s 315ms/step - loss: 0.4600 - accuracy: 0.8349 - val_loss: 0.6218 - val_accuracy: 0.7986
# Epoch 111/300
# 361/361 [==============================] - 115s 316ms/step - loss: 0.4732 - accuracy: 0.8329 - val_loss: 0.6270 - val_accuracy: 0.7804
# Epoch 112/300
# 361/361 [==============================] - 113s 312ms/step - loss: 0.4645 - accuracy: 0.8381 - val_loss: 0.6284 - val_accuracy: 0.7829
# Epoch 113/300
# 361/361 [==============================] - 112s 309ms/step - loss: 0.4521 - accuracy: 0.8390 - val_loss: 0.6102 - val_accuracy: 0.8075
# Epoch 114/300
# 361/361 [==============================] - 113s 313ms/step - loss: 0.4607 - accuracy: 0.8371 - val_loss: 0.6776 - val_accuracy: 0.7812
# Epoch 115/300
# 361/361 [==============================] - 114s 314ms/step - loss: 0.4637 - accuracy: 0.8389 - val_loss: 0.6346 - val_accuracy: 0.8047
# Epoch 116/300
# 361/361 [==============================] - 106s 293ms/step - loss: 0.4511 - accuracy: 0.8398 - val_loss: 0.6261 - val_accuracy: 0.7990
# Epoch 117/300
# 361/361 [==============================] - 106s 293ms/step - loss: 0.4595 - accuracy: 0.8342 - val_loss: 0.5962 - val_accuracy: 0.8051
# Epoch 118/300
# 361/361 [==============================] - 110s 303ms/step - loss: 0.4438 - accuracy: 0.8439 - val_loss: 0.5756 - val_accuracy: 0.8083
# Epoch 119/300
# 361/361 [==============================] - 116s 320ms/step - loss: 0.4383 - accuracy: 0.8426 - val_loss: 0.6854 - val_accuracy: 0.8015
# Epoch 120/300
# 361/361 [==============================] - 125s 344ms/step - loss: 0.4391 - accuracy: 0.8452 - val_loss: 0.6084 - val_accuracy: 0.8071
# Epoch 121/300
# 361/361 [==============================] - 142s 391ms/step - loss: 0.4387 - accuracy: 0.8449 - val_loss: 0.5745 - val_accuracy: 0.8116
# Epoch 122/300
# 361/361 [==============================] - 139s 383ms/step - loss: 0.4412 - accuracy: 0.8419 - val_loss: 0.6050 - val_accuracy: 0.7970
# Epoch 123/300
# 361/361 [==============================] - 127s 351ms/step - loss: 0.4500 - accuracy: 0.8412 - val_loss: 0.5798 - val_accuracy: 0.8261
# Epoch 124/300
# 361/361 [==============================] - 125s 343ms/step - loss: 0.4319 - accuracy: 0.8443 - val_loss: 0.5568 - val_accuracy: 0.8201
# Epoch 125/300
# 361/361 [==============================] - 111s 306ms/step - loss: 0.4387 - accuracy: 0.8432 - val_loss: 0.6116 - val_accuracy: 0.8059
# Epoch 126/300
# 361/361 [==============================] - 111s 306ms/step - loss: 0.4372 - accuracy: 0.8466 - val_loss: 0.6635 - val_accuracy: 0.7740
# Epoch 127/300
# 361/361 [==============================] - 106s 293ms/step - loss: 0.4375 - accuracy: 0.8433 - val_loss: 0.7693 - val_accuracy: 0.7501
# Epoch 128/300
# 361/361 [==============================] - 109s 301ms/step - loss: 0.4408 - accuracy: 0.8450 - val_loss: 0.6435 - val_accuracy: 0.7845
# Epoch 129/300
# 361/361 [==============================] - 98s 271ms/step - loss: 0.4249 - accuracy: 0.8489 - val_loss: 0.6618 - val_accuracy: 0.7736
# Epoch 130/300
# 361/361 [==============================] - 96s 266ms/step - loss: 0.4281 - accuracy: 0.8445 - val_loss: 0.6022 - val_accuracy: 0.8071
# Epoch 131/300
# 361/361 [==============================] - 98s 272ms/step - loss: 0.4275 - accuracy: 0.8504 - val_loss: 0.6011 - val_accuracy: 0.8108
# Epoch 132/300
# 361/361 [==============================] - 96s 265ms/step - loss: 0.4182 - accuracy: 0.8494 - val_loss: 0.6081 - val_accuracy: 0.7942
# Epoch 133/300
# 361/361 [==============================] - 97s 268ms/step - loss: 0.4291 - accuracy: 0.8459 - val_loss: 0.5850 - val_accuracy: 0.8148
# Epoch 134/300
# 361/361 [==============================] - 97s 267ms/step - loss: 0.4167 - accuracy: 0.8529 - val_loss: 0.6025 - val_accuracy: 0.8063
# Epoch 135/300
# 361/361 [==============================] - 96s 265ms/step - loss: 0.4131 - accuracy: 0.8540 - val_loss: 0.6650 - val_accuracy: 0.7893
# Epoch 136/300
# 361/361 [==============================] - 96s 266ms/step - loss: 0.4145 - accuracy: 0.8555 - val_loss: 0.6090 - val_accuracy: 0.8011
# Epoch 137/300
# 361/361 [==============================] - 95s 264ms/step - loss: 0.4160 - accuracy: 0.8520 - val_loss: 0.5956 - val_accuracy: 0.8047
# Epoch 138/300
# 361/361 [==============================] - 97s 267ms/step - loss: 0.4172 - accuracy: 0.8508 - val_loss: 0.5781 - val_accuracy: 0.8116
# Epoch 139/300
# 361/361 [==============================] - 100s 277ms/step - loss: 0.4137 - accuracy: 0.8552 - val_loss: 0.5665 - val_accuracy: 0.8217
# Epoch 140/300
# 361/361 [==============================] - 97s 269ms/step - loss: 0.4161 - accuracy: 0.8493 - val_loss: 0.5659 - val_accuracy: 0.8075
# Epoch 141/300
# 361/361 [==============================] - 111s 306ms/step - loss: 0.4060 - accuracy: 0.8563 - val_loss: 0.6010 - val_accuracy: 0.8039
# Epoch 142/300
# 361/361 [==============================] - 107s 297ms/step - loss: 0.4085 - accuracy: 0.8553 - val_loss: 0.6120 - val_accuracy: 0.8051
# Epoch 143/300
# 361/361 [==============================] - 105s 290ms/step - loss: 0.4094 - accuracy: 0.8547 - val_loss: 0.6006 - val_accuracy: 0.8168
# Epoch 144/300
# 361/361 [==============================] - ETA: 0s - loss: 0.4033 - accuracy: 0.8595Restoring model weights from the end of the best epoch: 124.
# 361/361 [==============================] - 103s 284ms/step - loss: 0.4033 - accuracy: 0.8595 - val_loss: 0.5865 - val_accuracy: 0.8023
# Epoch 144: early stopping

# %%
# Predict on the test set
y_pred = model.predict(test_generator)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Get true labels
y_true = np.argmax(test_generator.labels, axis=1)

class_names = label_columns

# Print classification report
print("Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=class_names))

# Compute and plot confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Calculate and print overall accuracy
accuracy = np.sum(y_pred_classes == y_true) / len(y_true)
print(f"Overall Accuracy: {accuracy:.4f}")
# Out:
# 2024-06-26 17:38:44.935939: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 78/78 [==============================] - 6s 65ms/step
# Classification Report:
#                   precision    recall  f1-score   support
#
#  antelope_duiker       0.59      0.69      0.64       357
#             bird       0.90      0.89      0.90       227
#            blank       0.58      0.50      0.54       323
#      civet_genet       0.90      0.95      0.92       380
#              hog       0.95      0.85      0.90       142
#          leopard       0.94      0.89      0.92       336
# monkey_prosimian       0.83      0.83      0.83       401
#           rodent       0.84      0.82      0.83       308
#
#         accuracy                           0.80      2474
#        macro avg       0.82      0.81      0.81      2474
#     weighted avg       0.80      0.80      0.80      2474
# Overall Accuracy: 0.8011
